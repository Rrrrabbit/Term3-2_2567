# %% [markdown]
# <a href="https://colab.research.google.com/github/Rrrrabbit/Term3-2_2567/blob/main/SED690-Image_Processing/Perspective.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SED690
#
# SIT@KMUTT
#
# 2025

# %% [markdown]
# Perspective transformation
#
# For perspective transformation, we need a 3x3 transformation matrix.
# - Straight lines will remain straight even after the transformation.
# - To find this transformation matrix, you need 4 points on the input image and corresponding points on the output image.
# - Among these 4 points, 3 of them should not be collinear.
# - Then the transformation matrix can be found by the function cv.getPerspectiveTransform.
# - Then apply cv.warpPerspective with this 3x3 transformation matrix.

# %% [markdown]
# ![korkai.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![tilted_korkai_marked.jpeg](data:image/jpeg;base64,...)

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt

# %%
# Read in some images
# You can download the tilted Thai alphabet image given above.

image_bgr = io.imread("/content/korkai.jfif")  # change it as needed.

# Need to convert to RGB for a proper display
image_rgb = cv.cvtColor(image_bgr, cv.COLOR_BGR2RGB)

print("Input image (Tilted ก. ไก่)")
cv2_imshow(image_rgb)
# Out:
# Input image (Tilted ก. ไก่)
# <PIL.Image.Image image mode=RGB size=464x436>

# %% [markdown]
# - Using the simple Paint program to find out about the needed four marked points (not shown here) of this image, we may use the follows.
#
# - In a clockwise manner: top left, top right, bottom right, and bottom left: e.g., (133,137),(400,193),(263,350),and (45,320).
# - Now, try to change and pick your own the marked points.

# %%
print(image_rgb.shape)
rows,cols,ch = image_rgb.shape

# In a clockwise manner: top left, top right, bottom right, and bottom left.
in_4pts = np.float32([[190,20],[450,140],[280,385],[10,400]]) # four marked input points

out_4pts = np.float32([[0,0],[400,0],[400,500],[0,400]])  # extended to the full size, using four marked ouput points

M = cv.getPerspectiveTransform(in_4pts,out_4pts)
dst = cv.warpPerspective(image_rgb,M,(rows,cols))

print("Transformed image")
cv2_imshow(dst)
# Out:
# (436, 464, 3)
# Transformed image
# <PIL.Image.Image image mode=RGB size=436x464>

# %%
# crop the image
cropped_image = dst[20:300,100:350]
print("Cropped image")
cv2_imshow(cropped_image)
# Out:
# Cropped image
# <PIL.Image.Image image mode=RGB size=250x280>

# %% [markdown]
# # Now try to fill in one color, say, orange, for a background.

# %%
# Write your code here.
print("Here is my work ......")
print("66130700360 - Kanchana Wanatarat")
# Out:
# Here is my work ......

# %%
import numpy as np
#import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
#from PIL import Image
#import matplotlib.pylab as plt

# %%
image_bgr = io.imread("/content/tilted_ThaiLicensePlate.jpg")

# Need to convert to RGB for a proper display
image_rgb = cv.cvtColor(image_bgr, cv.COLOR_BGR2RGB)

print("Input image")
cv2_imshow(image_rgb)
# Out:
# Input image
# <PIL.Image.Image image mode=RGB size=774x449>

# %%
print(image_rgb.shape)
rows,cols,ch = image_rgb.shape

# In a clockwise manner: top left, top right, bottom right, and bottom left.
in_4pts = np.float32([[195,195],[425,260],[410,375],[190,300]]) # four marked input points

out_4pts = np.float32([[0,0],[400,0],[400,170],[0,170]])  # extended to the full size, using four marked ouput points

M = cv.getPerspectiveTransform(in_4pts,out_4pts)
dst = cv.warpPerspective(image_rgb,M,(rows,cols))

print("Transformed image")
cv2_imshow(dst)
# Out:
# (449, 774, 3)
# Transformed image
# <PIL.Image.Image image mode=RGB size=449x774>

# %%
# crop the image
cropped_image = dst[0:180,0:400]
print("Cropped image")
cv2_imshow(cropped_image)
# Out:
# Cropped image
# <PIL.Image.Image image mode=RGB size=400x180>
